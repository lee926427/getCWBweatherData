# %%
import Ipynb_importer
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np
import datetime 
from package.getWeatherData import CwbOpenData as cwb
# Out:
# importing Jupyter notebook from /Users/peteryeh/Documents/python/aqi/package/getWeatherData.ipynb

# %%
auth = "CWB-8EE6A92A-B903-4AC3-ADF5-465DFF5987F2"
cwdData = cwb(auth)
payload = cwdData.update()

print(json_normalize(payload["location"]))
# Out:
# 200
# curUpdate  Time:2019-09-24T10:43:30+08:00
# prevUpdate Time:2019-09-24T10:43:30+08:00
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c65d51ab275a> in <module>
#       3 payload = cwdData.update()
#       4
# ----> 5 print(json_normalize())
#
# NameError: name 'json_normalize' is not defined

# %%
cwdData.update()
# Out:
# 200
# curUpdate  Time:2019-09-24T10:33:30+08:00
# prevUpdate Time:2019-09-24T10:33:30+08:00
# {'@xmlns': 'urn:cwb:gov:tw:cwbcommon:0.1',
#  'identifier': '1e908825-0199-454f-910c-769bf6e5803b',
#  'sender': 'weather@cwb.gov.tw',
#  'sent': '2019-09-24T10:33:30+08:00',
#  'status': 'Actual',
#  'msgType': 'Issue',
#  'dataid': 'CWB_A0003',
#  'scope': 'Public',
#  'dataset': None,
#  'location': [{'lat': '25.135130',
#    'lon': '121.732265',
#    'lat_wgs84': '25.13331389',
#    'lon_wgs84': '121.740475',
#    'locationName': '基隆',
#    'stationId': '466940',
#    'time': {'obsTime': '2019-09-24T10:30:00+08:00'},
#    'weatherElement': [{'elementName': 'ELEV',
#      'elementValue': {'value': '26.70'}},
#     {'elementName': 'WDIR', 'elementValue': {'value': '50'}},
#     {'elementName': 'WDSD', 'elementValue': {'value': '6'}},
#     {'elementName': 'TEMP', 'elementValue': {'value': '24.60'}},
#     {'elementName': 'HUMD', 'elementValue': {'value': '0.59'}},
# ...
